# %% [markdown]
# # TP - Utilisation d'API externes
#
# ## 1 - Openweathermap
#
# Nous allons utiliser une première API pour afficher la météo locale.
#
# Lisez le tutoriel suivant : https://knasmueller.net/using-the-open-weather-map-api-with-python
#
# Vous aurez donc besoin de créer un compte sur le site openweathermap.org et y récupérer des clés d'accès à l'API.

# %%
import requests
import json

api_key = "636c38d4823ec35febd86d4c24dd668a"   #votre clé d'API obtenue sur le site
lat = "45.518311"   #la latitude de l'endroit souhaité
lon = "-73.516125"   #la longitude de l'endroit souhaité
url = "https://api.openweathermap.org/data/2.5/onecall?lat=%s&lon=%s&appid=%s&units=metric" % (lat, lon, api_key)

response = requests.get(url)
data = json.loads(response.text)
print(data)
# Out:
# {'lat': 45.52, 'lon': -73.52, 'timezone': 'America/Toronto', 'timezone_offset': -14400, 'current': {'dt': 1598113262, 'sunrise': 1598090640, 'sunset': 1598140204, 'temp': 23.4, 'feels_like': 24.39, 'pressure': 1014, 'humidity': 69, 'dew_point': 17.39, 'uvi': 6.72, 'clouds': 20, 'visibility': 10000, 'wind_speed': 2.2, 'wind_deg': 242, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]}, 'minutely': [{'dt': 1598113320, 'precipitation': 0}, {'dt': 1598113380, 'precipitation': 0}, {'dt': 1598113440, 'precipitation': 0}, {'dt': 1598113500, 'precipitation': 0}, {'dt': 1598113560, 'precipitation': 0}, {'dt': 1598113620, 'precipitation': 0}, {'dt': 1598113680, 'precipitation': 0}, {'dt': 1598113740, 'precipitation': 0}, {'dt': 1598113800, 'precipitation': 0}, {'dt': 1598113860, 'precipitation': 0}, {'dt': 1598113920, 'precipitation': 0}, {'dt': 1598113980, 'precipitation': 0}, {'dt': 1598114040, 'precipitation': 0}, {'dt': 1598114100, 'precipitation': 0}, {'dt': 1598114160, 'precipitation': 0}, {'dt': 1598114220, 'precipitation': 0}, {'dt': 1598114280, 'precipitation': 0}, {'dt': 1598114340, 'precipitation': 0}, {'dt': 1598114400, 'precipitation': 0}, {'dt': 1598114460, 'precipitation': 0}, {'dt': 1598114520, 'precipitation': 0}, {'dt': 1598114580, 'precipitation': 0}, {'dt': 1598114640, 'precipitation': 0}, {'dt': 1598114700, 'precipitation': 0}, {'dt': 1598114760, 'precipitation': 0}, {'dt': 1598114820, 'precipitation': 0}, {'dt': 1598114880, 'precipitation': 0}, {'dt': 1598114940, 'precipitation': 0}, {'dt': 1598115000, 'precipitation': 0}, {'dt': 1598115060, 'precipitation': 0}, {'dt': 1598115120, 'precipitation': 0}, {'dt': 1598115180, 'precipitation': 0}, {'dt': 1598115240, 'precipitation': 0}, {'dt': 1598115300, 'precipitation': 0}, {'dt': 1598115360, 'precipitation': 0}, {'dt': 1598115420, 'precipitation': 0}, {'dt': 1598115480, 'precipitation': 0}, {'dt': 1598115540, 'precipitation': 0}, {'dt': 1598115600, 'precipitation': 0}, {'dt': 1598115660, 'precipitation': 0}, {'dt': 1598115720, 'precipitation': 0}, {'dt': 1598115780, 'precipitation': 0}, {'dt': 1598115840, 'precipitation': 0}, {'dt': 1598115900, 'precipitation': 0}, {'dt': 1598115960, 'precipitation': 0}, {'dt': 1598116020, 'precipitation': 0}, {'dt': 1598116080, 'precipitation': 0}, {'dt': 1598116140, 'precipitation': 0}, {'dt': 1598116200, 'precipitation': 0}, {'dt': 1598116260, 'precipitation': 0}, {'dt': 1598116320, 'precipitation': 0}, {'dt': 1598116380, 'precipitation': 0}, {'dt': 1598116440, 'precipitation': 0}, {'dt': 1598116500, 'precipitation': 0}, {'dt': 1598116560, 'precipitation': 0}, {'dt': 1598116620, 'precipitation': 0}, {'dt': 1598116680, 'precipitation': 0}, {'dt': 1598116740, 'precipitation': 0}, {'dt': 1598116800, 'precipitation': 0}, {'dt': 1598116860, 'precipitation': 0}, {'dt': 1598116920, 'precipitation': 0}], 'hourly': [{'dt': 1598112000, 'temp': 23.4, 'feels_like': 24.39, 'pressure': 1014, 'humidity': 69, 'dew_point': 17.39, 'clouds': 20, 'visibility': 10000, 'wind_speed': 2.2, 'wind_deg': 242, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'pop': 0.22}, {'dt': 1598115600, 'temp': 24.45, 'feels_like': 24.47, 'pressure': 1014, 'humidity': 56, 'dew_point': 15.11, 'clouds': 15, 'visibility': 10000, 'wind_speed': 2.33, 'wind_deg': 253, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'pop': 0.22}, {'dt': 1598119200, 'temp': 25.83, 'feels_like': 25.37, 'pressure': 1013, 'humidity': 46, 'dew_point': 13.34, 'clouds': 11, 'visibility': 10000, 'wind_speed': 2.14, 'wind_deg': 254, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'pop': 0.15}, {'dt': 1598122800, 'temp': 26.58, 'feels_like': 25.86, 'pressure': 1013, 'humidity': 40, 'dew_point': 11.89, 'clouds': 1, 'visibility': 10000, 'wind_speed': 1.86, 'wind_deg': 254, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'} ...

# %% [markdown]
# On obtient une structure de donnée de type json qu'on peut alors interroger ou mettre en forme proprement :

# %%
print(json.dumps(data, indent=4, sort_keys=False))  #Cette instruction permet de mettre en forme le contenu json
# Out:
# {
#     "lat": 45.52,
#     "lon": -73.52,
#     "timezone": "America/Toronto",
#     "timezone_offset": -14400,
#     "current": {
#         "dt": 1598113262,
#         "sunrise": 1598090640,
#         "sunset": 1598140204,
#         "temp": 23.4,
#         "feels_like": 24.39,
#         "pressure": 1014,
#         "humidity": 69,
#         "dew_point": 17.39,
#         "uvi": 6.72,
#         "clouds": 20,
#         "visibility": 10000,
#         "wind_speed": 2.2,
#         "wind_deg": 242,
#         "weather": [
#             {
#                 "id": 801,
#                 "main": "Clouds",
#                 "description": "few clouds",
#                 "icon": "02d"
#             }
#         ]
#     },
#     "minutely": [
#         {
#             "dt": 1598113320,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598113380,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598113440,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598113500,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598113560,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598113620,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598113680,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598113740,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598113800,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598113860,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598113920,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598113980,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114040,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114100,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114160,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114220,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114280,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114340,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114400,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114460,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114520,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114580,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114640,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114700,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114760,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114820,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114880,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598114940,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115000,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115060,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115120,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115180,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115240,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115300,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115360,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115420,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115480,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115540,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115600,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115660,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115720,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115780,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115840,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115900,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598115960,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116020,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116080,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116140,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116200,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116260,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116320,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116380,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116440,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116500,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116560,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116620,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116680,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116740,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116800,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116860,
#             "precipitation": 0
#         },
#         {
#             "dt": 1598116920,
#             "precipitation": 0
#         }
#     ],
#     "hourly": [
#         {
#             "dt": 1598112000,
#             "temp": 23.4,
#             "feels_like": 24.39,
#             "pressure": 1014,
#             "humidity": 69,
#             "dew_point": 17.39,
#             "clouds": 20,
#             "visibility": 10000,
#             "wind_speed": 2.2,
#             "wind_deg": 242,
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02d"
#                 }
#             ],
#             "pop": 0.22
#         },
#         {
#             "dt": 1598115600,
#             "temp": 24.45,
#             "feels_like": 24.47,
#             "pressure": 1014,
#             "humidity": 56,
#             "dew_point": 15.11,
#             "clouds": 15,
#             "visibility": 10000,
#             "wind_speed": 2.33,
#             "wind_deg": 253,
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02d"
#                 }
#             ],
#             "pop": 0.22
#         },
#         {
#             "dt": 1598119200,
#             "temp": 25.83,
#             "feels_like": 25.37,
#             "pressure": 1013,
#             "humidity": 46,
#             "dew_point": 13.34,
#             "clouds": 11,
#             "visibility": 10000,
#             "wind_speed": 2.14,
#             "wind_deg": 254,
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02d"
#                 }
#             ],
#             "pop": 0.15
#         },
#         {
#             "dt": 1598122800,
#             "temp": 26.58,
#             "feels_like": 25.86,
#             "pressure": 1013,
#             "humidity": 40,
#             "dew_point": 11.89,
#             "clouds": 1,
#             "visibility": 10000,
#             "wind_speed": 1.86,
#             "wind_deg": 254,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "pop": 0
#         },
#         {
#             "dt": 1598126400,
#             "temp": 26.84,
#             "feels_like": 26.2,
#             "pressure": 1013,
#             "humidity": 40,
#             "dew_point": 12.12,
#             "clouds": 3,
#             "visibility": 10000,
#             "wind_speed": 1.84,
#             "wind_deg": 234,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "pop": 0
#         },
#         {
#             "dt": 1598130000,
#             "temp": 26.31,
#             "feels_like": 25.58,
#             "pressure": 1013,
#             "humidity": 44,
#             "dew_point": 13.24,
#             "clouds": 3,
#             "visibility": 10000,
#             "wind_speed": 2.41,
#             "wind_deg": 231,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "pop": 0
#         },
#         {
#             "dt": 1598133600,
#             "temp": 25.48,
#             "feels_like": 24.89,
#             "pressure": 1013,
#             "humidity": 49,
#             "dew_point": 14.12,
#             "clouds": 3,
#             "visibility": 10000,
#             "wind_speed": 2.64,
#             "wind_deg": 237,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "pop": 0
#         },
#         {
#             "dt": 1598137200,
#             "temp": 24.21,
#             "feels_like": 23.76,
#             "pressure": 1013,
#             "humidity": 54,
#             "dew_point": 14.45,
#             "clouds": 3,
#             "visibility": 10000,
#             "wind_speed": 2.6,
#             "wind_deg": 238,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "pop": 0
#         },
#         {
#             "dt": 1598140800,
#             "temp": 22.91,
#             "feels_like": 22.67,
#             "pressure": 1014,
#             "humidity": 59,
#             "dew_point": 14.51,
#             "clouds": 3,
#             "visibility": 10000,
#             "wind_speed": 2.38,
#             "wind_deg": 248,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "pop": 0
#         },
#         {
#             "dt": 1598144400,
#             "temp": 22.21,
#             "feels_like": 22.3,
#             "pressure": 1014,
#             "humidity": 62,
#             "dew_point": 14.73,
#             "clouds": 0,
#             "visibility": 10000,
#             "wind_speed": 1.96,
#             "wind_deg": 226,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "pop": 0
#         },
#         {
#             "dt": 1598148000,
#             "temp": 21.3,
#             "feels_like": 21.56,
#             "pressure": 1015,
#             "humidity": 66,
#             "dew_point": 14.89,
#             "clouds": 18,
#             "visibility": 10000,
#             "wind_speed": 1.78,
#             "wind_deg": 170,
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "pop": 0
#         },
#         {
#             "dt": 1598151600,
#             "temp": 20.48,
#             "feels_like": 20.39,
#             "pressure": 1014,
#             "humidity": 69,
#             "dew_point": 14.61,
#             "clouds": 45,
#             "visibility": 10000,
#             "wind_speed": 2.23,
#             "wind_deg": 164,
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ],
#             "pop": 0
#         },
#         {
#             "dt": 1598155200,
#             "temp": 19.74,
#             "feels_like": 19.17,
#             "pressure": 1015,
#             "humidity": 71,
#             "dew_point": 14.51,
#             "clouds": 59,
#             "visibility": 10000,
#             "wind_speed": 2.78,
#             "wind_deg": 181,
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "pop": 0
#         },
#         {
#             "dt": 1598158800,
#             "temp": 19.37,
#             "feels_like": 19.13,
#             "pressure": 1014,
#             "humidity": 74,
#             "dew_point": 14.79,
#             "clouds": 67,
#             "visibility": 10000,
#             "wind_speed": 2.46,
#             "wind_deg": 177,
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "pop": 0
#         },
#         {
#             "dt": 1598162400,
#             "temp": 19.24,
#             "feels_like": 19.12,
#             "pressure": 1014,
#             "humidity": 75,
#             "dew_point": 14.9,
#             "clouds": 73,
#             "visibility": 10000,
#             "wind_speed": 2.32,
#             "wind_deg": 175,
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "pop": 0
#         },
#         {
#             "dt": 1598166000,
#             "temp": 19.04,
#             "feels_like": 18.83,
#             "pressure": 1014,
#             "humidity": 76,
#             "dew_point": 14.72,
#             "clouds": 100,
#             "visibility": 10000,
#             "wind_speed": 2.46,
#             "wind_deg": 174,
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "pop": 0
#         },
#         {
#             "dt": 1598169600,
#             "temp": 18.74,
#             "feels_like": 18.39,
#             "pressure": 1014,
#             "humidity": 76,
#             "dew_point": 14.62,
#             "clouds": 98,
#             "visibility": 10000,
#             "wind_speed": 2.51,
#             "wind_deg": 199,
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "pop": 0.17
#         },
#         {
#             "dt": 1598173200,
#             "temp": 18.92,
#             "feels_like": 18.96,
#             "pressure": 1014,
#             "humidity": 77,
#             "dew_point": 14.82,
#             "clouds": 98,
#             "visibility": 10000,
#             "wind_speed": 2.14,
#             "wind_deg": 201,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "pop": 0.38,
#             "rain": {
#                 "1h": 0.43
#             }
#         },
#         {
#             "dt": 1598176800,
#             "temp": 18.95,
#             "feels_like": 19.06,
#             "pressure": 1015,
#             "humidity": 79,
#             "dew_point": 15.32,
#             "clouds": 98,
#             "visibility": 9712,
#             "wind_speed": 2.26,
#             "wind_deg": 197,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "pop": 0.78,
#             "rain": {
#                 "1h": 0.65
#             }
#         },
#         {
#             "dt": 1598180400,
#             "temp": 19.05,
#             "feels_like": 19.7,
#             "pressure": 1015,
#             "humidity": 81,
#             "dew_point": 15.75,
#             "clouds": 99,
#             "visibility": 10000,
#             "wind_speed": 1.75,
#             "wind_deg": 207,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "pop": 0.82,
#             "rain": {
#                 "1h": 0.49
#             }
#         },
#         {
#             "dt": 1598184000,
#             "temp": 19.63,
#             "feels_like": 20.52,
#             "pressure": 1015,
#             "humidity": 80,
#             "dew_point": 16.24,
#             "clouds": 99,
#             "visibility": 10000,
#             "wind_speed": 1.61,
#             "wind_deg": 227,
#             "weather": [
#                 {
#                     "id": 501,
#                     "main": "Rain",
#                     "description": "moderate rain",
#                     "icon": "10d"
#                 }
#             ],
#             "pop": 0.82,
#             "rain": {
#                 "1h": 1.14
#             }
#         },
#         {
#             "dt": 1598187600,
#             "temp": 21.24,
#             "feels_like": 21.85,
#             "pressure": 1015,
#             "humidity": 74,
#             "dew_point": 16.6,
#             "clouds": 100,
#             "visibility": 10000,
#             "wind_speed": 2.19,
#             "wind_deg": 213,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "pop": 0.77,
#             "rain": {
#                 "1h": 0.91
#             }
#         },
#         {
#             "dt": 1598191200,
#             "temp": 22.57,
#             "feels_like": 23.11,
#             "pressure": 1015,
#             "humidity": 70,
#             "dew_point": 16.98,
#             "clouds": 100,
#             "visibility": 10000,
#             "wind_speed": 2.52,
#             "wind_deg": 232,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "pop": 0.85,
#             "rain": {
#                 "1h": 0.51
#             }
#         },
#         {
#             "dt": 1598194800,
#             "temp": 22.96,
#             "feels_like": 23.63,
#             "pressure": 1015,
#             "humidity": 72,
#             "dew_point": 17.74,
#             "clouds": 100,
#             "visibility": 10000,
#             "wind_speed": 2.82,
#             "wind_deg": 225,
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "pop": 0.84
#         },
#         {
#             "dt": 1598198400,
#             "temp": 23.92,
#             "feels_like": 24.86,
#             "pressure": 1015,
#             "humidity": 71,
#             "dew_point": 18.39,
#             "clouds": 100,
#             "visibility": 10000,
#             "wind_speed": 2.85,
#             "wind_deg": 251,
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "pop": 0.88
#         },
#         {
#             "dt": 1598202000,
#             "temp": 25.03,
#             "feels_like": 25.94,
#             "pressure": 1015,
#             "humidity": 66,
#             "dew_point": 18.33,
#             "clouds": 96,
#             "visibility": 10000,
#             "wind_speed": 2.83,
#             "wind_deg": 275,
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "pop": 0.87
#         },
#         {
#             "dt": 1598205600,
#             "temp": 24.08,
#             "feels_like": 25.32,
#             "pressure": 1015,
#             "humidity": 71,
#             "dew_point": 18.5,
#             "clouds": 96,
#             "visibility": 10000,
#             "wind_speed": 2.52,
#             "wind_deg": 289,
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "pop": 0.71
#         },
#         {
#             "dt": 1598209200,
#             "temp": 26.58,
#             "feels_like": 27.52,
#             "pressure": 1015,
#             "humidity": 58,
#             "dew_point": 17.82,
#             "clouds": 86,
#             "visibility": 10000,
#             "wind_speed": 2.42,
#             "wind_deg": 295,
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "pop": 0.52
#         },
#         {
#             "dt": 1598212800,
#             "temp": 27.06,
#             "feels_like": 28.06,
#             "pressure": 1014,
#             "humidity": 55,
#             "dew_point": 17.29,
#             "clouds": 68,
#             "visibility": 10000,
#             "wind_speed": 2.1,
#             "wind_deg": 315,
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "pop": 0.52
#         },
#         {
#             "dt": 1598216400,
#             "temp": 26.63,
#             "feels_like": 27.84,
#             "pressure": 1014,
#             "humidity": 58,
#             "dew_point": 17.84,
#             "clouds": 62,
#             "visibility": 10000,
#             "wind_speed": 2.07,
#             "wind_deg": 350,
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "pop": 0.65
#         },
#         {
#             "dt": 1598220000,
#             "temp": 25.08,
#             "feels_like": 26.08,
#             "pressure": 1014,
#             "humidity": 67,
#             "dew_point": 18.73,
#             "clouds": 72,
#             "visibility": 10000,
#             "wind_speed": 2.88,
#             "wind_deg": 20,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "pop": 0.85,
#             "rain": {
#                 "1h": 0.23
#             }
#         },
#         {
#             "dt": 1598223600,
#             "temp": 22.62,
#             "feels_like": 23.06,
#             "pressure": 1014,
#             "humidity": 79,
#             "dew_point": 18.95,
#             "clouds": 77,
#             "visibility": 10000,
#             "wind_speed": 3.86,
#             "wind_deg": 43,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "pop": 0.88,
#             "rain": {
#                 "1h": 0.29
#             }
#         },
#         {
#             "dt": 1598227200,
#             "temp": 21.24,
#             "feels_like": 22.38,
#             "pressure": 1015,
#             "humidity": 84,
#             "dew_point": 18.47,
#             "clouds": 81,
#             "visibility": 10000,
#             "wind_speed": 2.63,
#             "wind_deg": 70,
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "pop": 0.88
#         },
#         {
#             "dt": 1598230800,
#             "temp": 21.22,
#             "feels_like": 22.96,
#             "pressure": 1015,
#             "humidity": 84,
#             "dew_point": 18.41,
#             "clouds": 100,
#             "visibility": 10000,
#             "wind_speed": 1.75,
#             "wind_deg": 104,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "pop": 0.57,
#             "rain": {
#                 "1h": 0.92
#             }
#         },
#         {
#             "dt": 1598234400,
#             "temp": 21.2,
#             "feels_like": 23.52,
#             "pressure": 1015,
#             "humidity": 84,
#             "dew_point": 18.57,
#             "clouds": 100,
#             "visibility": 8176,
#             "wind_speed": 0.91,
#             "wind_deg": 14,
#             "weather": [
#                 {
#                     "id": 501,
#                     "main": "Rain",
#                     "description": "moderate rain",
#                     "icon": "10n"
#                 }
#             ],
#             "pop": 0.76,
#             "rain": {
#                 "1h": 1.17
#             }
#         },
#         {
#             "dt": 1598238000,
#             "temp": 20.65,
#             "feels_like": 22.33,
#             "pressure": 1015,
#             "humidity": 85,
#             "dew_point": 18.18,
#             "clouds": 100,
#             "visibility": 10000,
#             "wind_speed": 1.61,
#             "wind_deg": 30,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "pop": 0.84,
#             "rain": {
#                 "1h": 0.49
#             }
#         },
#         {
#             "dt": 1598241600,
#             "temp": 20.07,
#             "feels_like": 21.14,
#             "pressure": 1015,
#             "humidity": 86,
#             "dew_point": 17.71,
#             "clouds": 100,
#             "visibility": 8424,
#             "wind_speed": 2.25,
#             "wind_deg": 39,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "pop": 0.95,
#             "rain": {
#                 "1h": 0.4
#             }
#         },
#         {
#             "dt": 1598245200,
#             "temp": 19.59,
#             "feels_like": 20.65,
#             "pressure": 1015,
#             "humidity": 87,
#             "dew_point": 17.42,
#             "clouds": 100,
#             "visibility": 10000,
#             "wind_speed": 2.1,
#             "wind_deg": 48,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "pop": 0.95,
#             "rain": {
#                 "1h": 0.71
#             }
#         },
#         {
#             "dt": 1598248800,
#             "temp": 19.26,
#             "feels_like": 20.05,
#             "pressure": 1014,
#             "humidity": 88,
#             "dew_point": 17.37,
#             "clouds": 100,
#             "visibility": 10000,
#             "wind_speed": 2.4,
#             "wind_deg": 29,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "pop": 0.91,
#             "rain": {
#                 "1h": 0.95
#             }
#         },
#         {
#             "dt": 1598252400,
#             "temp": 18.98,
#             "feels_like": 19.54,
#             "pressure": 1014,
#             "humidity": 88,
#             "dew_point": 17,
#             "clouds": 100,
#             "visibility": 10000,
#             "wind_speed": 2.57,
#             "wind_deg": 34,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "pop": 0.69,
#             "rain": {
#                 "1h": 0.43
#             }
#         },
#         {
#             "dt": 1598256000,
#             "temp": 18.66,
#             "feels_like": 19.16,
#             "pressure": 1014,
#             "humidity": 88,
#             "dew_point": 16.71,
#             "clouds": 100,
#             "visibility": 10000,
#             "wind_speed": 2.48,
#             "wind_deg": 34,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "pop": 0.72,
#             "rain": {
#                 "1h": 0.36
#             }
#         },
#         {
#             "dt": 1598259600,
#             "temp": 18.42,
#             "feels_like": 18.94,
#             "pressure": 1014,
#             "humidity": 88,
#             "dew_point": 16.51,
#             "clouds": 100,
#             "visibility": 10000,
#             "wind_speed": 2.31,
#             "wind_deg": 51,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "pop": 0.7,
#             "rain": {
#                 "1h": 0.13
#             }
#         },
#         {
#             "dt": 1598263200,
#             "temp": 18.19,
#             "feels_like": 18.81,
#             "pressure": 1014,
#             "humidity": 89,
#             "dew_point": 16.39,
#             "clouds": 95,
#             "visibility": 10000,
#             "wind_speed": 2.14,
#             "wind_deg": 37,
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "pop": 0.55
#         },
#         {
#             "dt": 1598266800,
#             "temp": 18.06,
#             "feels_like": 18.46,
#             "pressure": 1015,
#             "humidity": 88,
#             "dew_point": 16.17,
#             "clouds": 86,
#             "visibility": 10000,
#             "wind_speed": 2.29,
#             "wind_deg": 38,
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "pop": 0.47
#         },
#         {
#             "dt": 1598270400,
#             "temp": 18.93,
#             "feels_like": 19.66,
#             "pressure": 1015,
#             "humidity": 85,
#             "dew_point": 16.39,
#             "clouds": 84,
#             "visibility": 10000,
#             "wind_speed": 1.99,
#             "wind_deg": 43,
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "pop": 0.4
#         },
#         {
#             "dt": 1598274000,
#             "temp": 20.01,
#             "feels_like": 20.94,
#             "pressure": 1014,
#             "humidity": 81,
#             "dew_point": 16.76,
#             "clouds": 89,
#             "visibility": 10000,
#             "wind_speed": 1.87,
#             "wind_deg": 41,
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "pop": 0
#         },
#         {
#             "dt": 1598277600,
#             "temp": 20.54,
#             "feels_like": 21.65,
#             "pressure": 1014,
#             "humidity": 80,
#             "dew_point": 17.04,
#             "clouds": 94,
#             "visibility": 10000,
#             "wind_speed": 1.8,
#             "wind_deg": 35,
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "pop": 0.04
#         },
#         {
#             "dt": 1598281200,
#             "temp": 21.21,
#             "feels_like": 22.54,
#             "pressure": 1014,
#             "humidity": 78,
#             "dew_point": 17.27,
#             "clouds": 96,
#             "visibility": 10000,
#             "wind_speed": 1.63,
#             "wind_deg": 28,
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "pop": 0.04
#         }
#     ],
#     "daily": [
#         {
#             "dt": 1598112000,
#             "sunrise": 1598090640,
#             "sunset": 1598140204,
#             "temp": {
#                 "day": 23.4,
#                 "min": 20.5,
#                 "max": 25.68,
#                 "night": 20.5,
#                 "eve": 25.68,
#                 "morn": 23.4
#             },
#             "feels_like": {
#                 "day": 24.79,
#                 "night": 20.42,
#                 "eve": 25.31,
#                 "morn": 24.79
#             },
#             "pressure": 1014,
#             "humidity": 69,
#             "dew_point": 17.39,
#             "wind_speed": 1.64,
#             "wind_deg": 234,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": 20,
#             "pop": 0.22,
#             "rain": 0.11,
#             "uvi": 6.72
#         },
#         {
#             "dt": 1598198400,
#             "sunrise": 1598177114,
#             "sunset": 1598226499,
#             "temp": {
#                 "day": 22.96,
#                 "min": 18.92,
#                 "max": 26.63,
#                 "night": 20.65,
#                 "eve": 26.63,
#                 "morn": 18.92
#             },
#             "feels_like": {
#                 "day": 23.63,
#                 "night": 22.33,
#                 "eve": 27.84,
#                 "morn": 18.96
#             },
#             "pressure": 1015,
#             "humidity": 72,
#             "dew_point": 17.74,
#             "wind_speed": 2.82,
#             "wind_deg": 225,
#             "weather": [
#                 {
#                     "id": 501,
#                     "main": "Rain",
#                     "description": "moderate rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": 100,
#             "pop": 0.88,
#             "rain": 7.29,
#             "uvi": 6.7
#         },
#         {
#             "dt": 1598284800,
#             "sunrise": 1598263587,
#             "sunset": 1598312794,
#             "temp": {
#                 "day": 21.21,
#                 "min": 18.42,
#                 "max": 24.07,
#                 "night": 20.5,
#                 "eve": 24.07,
#                 "morn": 18.42
#             },
#             "feels_like": {
#                 "day": 22.54,
#                 "night": 22.04,
#                 "eve": 25.52,
#                 "morn": 18.94
#             },
#             "pressure": 1014,
#             "humidity": 78,
#             "dew_point": 17.27,
#             "wind_speed": 1.63,
#             "wind_deg": 28,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": 96,
#             "pop": 0.7,
#             "rain": 0.91,
#             "uvi": 6.4
#         },
#         {
#             "dt": 1598371200,
#             "sunrise": 1598350061,
#             "sunset": 1598399088,
#             "temp": {
#                 "day": 23.37,
#                 "min": 15.77,
#                 "max": 23.81,
#                 "night": 15.77,
#                 "eve": 20.34,
#                 "morn": 20.55
#             },
#             "feels_like": {
#                 "day": 20.15,
#                 "night": 11.65,
#                 "eve": 15.52,
#                 "morn": 20.34
#             },
#             "pressure": 1006,
#             "humidity": 55,
#             "dew_point": 14.04,
#             "wind_speed": 6.32,
#             "wind_deg": 301,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": 85,
#             "pop": 0.75,
#             "rain": 1.21,
#             "uvi": 6.34
#         },
#         {
#             "dt": 1598457600,
#             "sunrise": 1598436534,
#             "sunset": 1598485381,
#             "temp": {
#                 "day": 15.63,
#                 "min": 12.01,
#                 "max": 19.35,
#                 "night": 13.25,
#                 "eve": 19.35,
#                 "morn": 12.01
#             },
#             "feels_like": {
#                 "day": 10.88,
#                 "night": 8.1,
#                 "eve": 13.38,
#                 "morn": 7.22
#             },
#             "pressure": 1013,
#             "humidity": 41,
#             "dew_point": 2.7,
#             "wind_speed": 4.5,
#             "wind_deg": 298,
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ],
#             "clouds": 31,
#             "pop": 0,
#             "uvi": 6.64
#         },
#         {
#             "dt": 1598544000,
#             "sunrise": 1598523007,
#             "sunset": 1598571673,
#             "temp": {
#                 "day": 16.34,
#                 "min": 11.06,
#                 "max": 20.79,
#                 "night": 15.77,
#                 "eve": 20.79,
#                 "morn": 11.06
#             },
#             "feels_like": {
#                 "day": 13.12,
#                 "night": 13.16,
#                 "eve": 16.92,
#                 "morn": 6.64
#             },
#             "pressure": 1011,
#             "humidity": 47,
#             "dew_point": 5.11,
#             "wind_speed": 3,
#             "wind_deg": 307,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": 0,
#             "pop": 0,
#             "uvi": 6.38
#         },
#         {
#             "dt": 1598630400,
#             "sunrise": 1598609481,
#             "sunset": 1598657965,
#             "temp": {
#                 "day": 17.64,
#                 "min": 11.96,
#                 "max": 19.53,
#                 "night": 15.31,
#                 "eve": 18.69,
#                 "morn": 11.96
#             },
#             "feels_like": {
#                 "day": 15.1,
#                 "night": 13.86,
#                 "eve": 15.97,
#                 "morn": 10.13
#             },
#             "pressure": 1012,
#             "humidity": 41,
#             "dew_point": 4.41,
#             "wind_speed": 1.81,
#             "wind_deg": 103,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": 65,
#             "pop": 0.47,
#             "rain": 0.19,
#             "uvi": 5.18
#         },
#         {
#             "dt": 1598716800,
#             "sunrise": 1598695954,
#             "sunset": 1598744256,
#             "temp": {
#                 "day": 20.25,
#                 "min": 15.08,
#                 "max": 22.57,
#                 "night": 17.92,
#                 "eve": 22.57,
#                 "morn": 15.08
#             },
#             "feels_like": {
#                 "day": 18.22,
#                 "night": 16.28,
#                 "eve": 19.04,
#                 "morn": 14.09
#             },
#             "pressure": 999,
#             "humidity": 70,
#             "dew_point": 14.8,
#             "wind_speed": 5,
#             "wind_deg": 244,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": 71,
#             "pop": 1,
#             "rain": 1.72,
#             "uvi": 5.29
#         }
#     ]
# }

# %% [markdown]
# Un contenu json, une fois chargé en mémoire (lors de l'instruction <code>data = json.loads(response.text)</code> devient un dictionnaire Python et on peut alors accéder aux informations grâce aux clés.

# %%
print(data["lat"])
print(data["current"])
# Out:
# 45.52
# {'dt': 1598113262, 'sunrise': 1598090640, 'sunset': 1598140204, 'temp': 23.4, 'feels_like': 24.39, 'pressure': 1014, 'humidity': 69, 'dew_point': 17.39, 'uvi': 6.72, 'clouds': 20, 'visibility': 10000, 'wind_speed': 2.2, 'wind_deg': 242, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]}

# %% [markdown]
# On voit dans l'exemple précédent que <code>data["current]</code> est lui même un dictionnaire, donc on peut accéder aux informations spécifiques avec une succession de crochets :

# %%
print(data["current"])          # le dictionnaire current
print(data["current"]["temp"])  # la valeur de la clé temp du dictionnaire current
# Out:
# {'dt': 1598113262, 'sunrise': 1598090640, 'sunset': 1598140204, 'temp': 23.4, 'feels_like': 24.39, 'pressure': 1014, 'humidity': 69, 'dew_point': 17.39, 'uvi': 6.72, 'clouds': 20, 'visibility': 10000, 'wind_speed': 2.2, 'wind_deg': 242, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]}
# 23.4

# %% [markdown]
# Un autre exemple :

# %%
print(data["daily"][0])          # les prévisions du jour car data["daily"] est une liste de 8 valeurs des prochains jours
print(data["daily"][7])          # les prévisions dans une semaine
# Out:
# {'dt': 1598112000, 'sunrise': 1598090640, 'sunset': 1598140204, 'temp': {'day': 23.4, 'min': 20.5, 'max': 25.68, 'night': 20.5, 'eve': 25.68, 'morn': 23.4}, 'feels_like': {'day': 24.79, 'night': 20.42, 'eve': 25.31, 'morn': 24.79}, 'pressure': 1014, 'humidity': 69, 'dew_point': 17.39, 'wind_speed': 1.64, 'wind_deg': 234, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'clouds': 20, 'pop': 0.22, 'rain': 0.11, 'uvi': 6.72}
# {'dt': 1598716800, 'sunrise': 1598695954, 'sunset': 1598744256, 'temp': {'day': 20.25, 'min': 15.08, 'max': 22.57, 'night': 17.92, 'eve': 22.57, 'morn': 15.08}, 'feels_like': {'day': 18.22, 'night': 16.28, 'eve': 19.04, 'morn': 14.09}, 'pressure': 999, 'humidity': 70, 'dew_point': 14.8, 'wind_speed': 5, 'wind_deg': 244, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'clouds': 71, 'pop': 1, 'rain': 1.72, 'uvi': 5.29}

# %% [markdown]
# ### Exercice
# Maintenant que vous avez vu comment accéder aux données météo renvoyées par l'API openweathermap, créez un petit programme qui affiche un bulletin meteo d'aujourd'hui et de demain dans deux villes différentes de votre choix.
# L'affichage doit-être esthétique et lisible et doit contenir les informations clés (soleil, nuages, ..., température min, max, ressenties), vous pouvez afficher les informations en anglais.
